# %%
data = "..."
potion_count = {"A": 0, "B": 1, "C": 3}
count_total = 0
for letter,  in range(0, len(data), 2):
    count_total = count_total + potion_count[letter]
print(count_total)
# Out:
# 1306

# %%
data = "..."
potion_count = {"A": 0, "B": 1, "C": 3, "x": 0, "D":5}
count_total = 0
steps = 0
for letter in range(int(len(data)/2)):
    count_total = count_total + potion_count[data[steps]]
    count_total = count_total + potion_count[data[steps + 1]]
    if data[steps] != "x" and data[steps + 1] != "x":
        count_total = count_total + 2
    
    steps = steps + 2
    
print(count_total)
# Out:
# 5526

# %%
data = "..."
potion_count = {"A": 0, "B": 1, "C": 3, "x": 0, "D":5}
count_total = 0
steps = 0
for letter in range(int(len(data)/3)):
    count_total = count_total + potion_count[data[steps]]
    count_total = count_total + potion_count[data[steps + 1]]
    count_total = count_total + potion_count[data[steps + 2]]
    xes = [data[steps], data[steps + 1], data[steps + 2]].count("x")
    if xes == 0:
        count_total = count_total + 6
    if xes == 1:
        count_total = count_total + 2
    steps = steps + 3
    
print(count_total)
# Out:
# 27581
